# %%
import pandas as pd
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
df.groupby(['Pclass', 'Sex'])['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby(['Pclass', 'Sex'])['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('Pclass')['Survived'].mean().plot(kind='bar')
plt.show()

# %%
df.groupby('Pclass')['Survived'].mean().plot(kind='bar')
plt.title('Survival Rate According to Pclass')
plt.xlabel('Pclass')
plt.ylabel('Survival Rate')
plt.show()

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='bar')
plt.show()

# %%
df.groupby('Age')['Survived'].mean()
# Out:
# Age
# 0.42     1.0
# 0.67     1.0
# 0.75     1.0
# 0.83     1.0
# 0.92     1.0
#         ...
# 70.00    0.0
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 80.00    1.0
# Name: Survived, Length: 88, dtype: float64

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])
df.groupby('AgeGroup')['Survived'].mean()*100
# Out:
# /tmp/ipykernel_2085/488698101.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('AgeGroup')['Survived'].mean()*100
# AgeGroup
# Child          57.971014
# Teen           42.857143
# Young Adult    38.268156
# Adult          40.000000
# Senior         22.727273
# Name: Survived, dtype: float64

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])
df.groupby(['AgeGroup', 'Sex'])['Survived'].mean()*100
# Out:
# /tmp/ipykernel_2085/1274860880.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['AgeGroup', 'Sex'])['Survived'].mean()*100
# AgeGroup     Sex
# Child        female     59.375000
#              male       56.756757
# Teen         female     75.000000
#              male        8.823529
# Young Adult  female     78.333333
#              male       18.067227
# Adult        female     77.142857
#              male       19.200000
# Senior       female    100.000000
#              male       10.526316
# Name: Survived, dtype: float64

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])
df.groupby(['AgeGroup', 'Sex', 'Pclass'])['Survived'].mean()*100
# Out:
# /tmp/ipykernel_2085/3386748752.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['AgeGroup', 'Sex', 'Pclass'])['Survived'].mean()*100
# AgeGroup     Sex     Pclass
# Child        female  1           0.000000
#                      2         100.000000
#                      3          47.826087
#              male    1         100.000000
#                      2         100.000000
#                      3          36.000000
# Teen         female  1         100.000000
#                      2         100.000000
#                      3          55.000000
#              male    1          50.000000
#                      2           0.000000
#                      3           7.692308
# Young Adult  female  1          97.222222
#                      2          92.500000
#                      3          50.000000
#              male    1          50.000000
#                      2           7.407407
#                      3          15.584416
# Adult        female  1          97.222222
#                      2          85.000000
#                      3          14.285714
#              male    1          37.037037
#                      2           3.703704
#                      3           6.818182
# Senior       female  1         100.000000
#                      2                NaN
#                      3         100.000000
#              male    1           8.333333
#                      2          33.333333
#                      3           0.000000
# Name: Survived, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# AgeGroup       177
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# AgeGroup       177
# dtype: int64

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 12, 18, 35, 60, 100], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# AgeGroup         0
# dtype: int64

# %%
df['Cabin'] = df['Cabin'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# AgeGroup       0
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# AgeGroup       0
# dtype: int64
